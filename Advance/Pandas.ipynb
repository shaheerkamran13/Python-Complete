# %% [markdown]
# # Pandas
#
# - Data Manipulation Library
# - Widely used in data analysis and data cleaning
#
# - Provides Series and DataFrame.
#
# - Series: A one-dimensional array  like object.
#
# - DataFrame: A two-dimensional, size-mutable and heterogenous tabular data structure with labeled axes (rows and columns)

# %%
# Series
# A panadas series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table

import pandas as pd

data = [1,2,3,4,5]
series = pd.Series(data)
print('Series: \n', series)
print(type(series))
# Out:
# Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
# Create a series from dictionary
data = {'a': 1, 'b': 2, 'c': 3}

series_dict =  pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]

index = ['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# DataFrame
# Create a DataFrame from a dictionary of list

data = {
    'Name': ["Bob", 'Tom', 'John'],
    'Age': [25,30,45],
    'City': ['Multan','Islamabad', 'Lahore']
}


df = pd.DataFrame(data)
print(df)

print(type(df))
# Out:
#    Name  Age       City
# 0   Bob   25     Multan
# 1   Tom   30  Islamabad
# 2  John   45     Lahore
# <class 'pandas.DataFrame'>

# %%
import numpy as np

np.array(df)
# Out:
# array([['Bob', 25, 'Multan'],
#        ['Tom', 30, 'Islamabad'],
#        ['John', 45, 'Lahore']], dtype=object)

# %%
# Create a dataframe from a list of dictionaries

data = [
    {'Name': "Bob", 'Age':23, 'City': 'Islamabad'},
    {'Name': "John", 'Age':20, 'City': 'Islamabad'},
    {'Name': "Bappy", 'Age':32, 'City': 'Islamabad'},
    {'Name': "Jack", 'Age':19, 'City': 'Islamabad'},

]

df = pd.DataFrame(data)
print(df)

print(type(df))
# Out:
#     Name  Age       City
# 0    Bob   23  Islamabad
# 1   John   20  Islamabad
# 2  Bappy   32  Islamabad
# 3   Jack   19  Islamabad
# <class 'pandas.DataFrame'>

# %%
df = pd.read_csv('test_data_itunes.csv')
df = df.head(3) # first 5 records

df
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
df.tail(5) # last 5 records
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
# Accessing the data from DataFrame

data
# Out:
# [{'Name': 'Bob', 'Age': 23, 'City': 'Islamabad'},
#  {'Name': 'John', 'Age': 20, 'City': 'Islamabad'},
#  {'Name': 'Bappy', 'Age': 32, 'City': 'Islamabad'},
#  {'Name': 'Jack', 'Age': 19, 'City': 'Islamabad'}]

# %%
df
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
type(df['artist_name'])
# Out:
# pandas.Series

# %%
df.loc[0] # Location
# Out:
# track_id                                                    1624932774
# track_name                                                        POP!
# artist_name                                                     NAYEON
# collection_name                                              IM NAYEON
# album_artist                                                       NaN
# genre                                                            Dance
# rating                                                           Clean
# track_price                                                       1.29
# collection_price                                                  6.99
# release_date                                      2022-06-24T12:00:00Z
# track_time_millis                                               168107
# country                                                            USA
# currency                                                           USD
# ...

# %%
df.iloc[1:]  # Index Location
# Out:
#      track_id                track_name                  artist_name  \
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 1             202019     USA      USD
# 2             247165     USA      USD
#
#                                          preview_url  \
# 1  https://audio-ssl.itunes.apple.com/itunes-asse...
# 2  https://audio-ssl.itunes.apple.com/itunes-asse...
#
#                                          artwork_url
# ...

# %%
df.at[0,'artist_name']
# Out:
# 'NAYEON'

# %%
# Accessing a specified element

df.at[1,'track_name']
# Out:
# 'Riptide'

# %%
# Accessing a specified element - with iat

df.iat[2,2]
# Out:
# 'The Chainsmokers & Coldplay'

# %%
# Data Manipulation with DataFrame

df
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
df['Salary'] = [50000,60000,70000] # Adding a column

df['Artist_age'] = [23,54,60]

# %%
# Deleting a column

df.drop('Salary', axis=1, inplace = True) # Does not save the state of data frame, it is temporary

# %%
df
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
# Add age to column

df['Artist_age'] = df['Artist_age'] + 1

df
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
df.drop(2)
# Out:
#      track_id track_name artist_name                         collection_name  \
# 0  1624932774       POP!      NAYEON                               IM NAYEON
# 1  1022164261    Riptide   Vance Joy  Dream Your Life Away (Special Edition)
#
#   album_artist        genre rating  track_price  collection_price  \
# 0          NaN        Dance  Clean         1.29              6.99
# 1          NaN  Alternative  Clean         1.29              9.99
#
#            release_date  track_time_millis country currency  \
# 0  2022-06-24T12:00:00Z             168107     USA      USD
# 1  2013-03-22T07:00:00Z             202019     USA      USD
#
#                                          preview_url  \
# 0  https://audio-ssl.itunes.apple.com/itunes-asse...
# 1  https://audio-ssl.itunes.apple.com/itunes-asse...
#
#                                          artwork_url  Artist_age
# 0  https://is1-ssl.mzstatic.com/image/thumb/Music...          25
# ...

# %%
df
# Out:
#      track_id                track_name                  artist_name  \
# 0  1624932774                      POP!                       NAYEON
# 1  1022164261                   Riptide                    Vance Joy
# 2  1207120448  Something Just Like This  The Chainsmokers & Coldplay
#
#                           collection_name      album_artist        genre  \
# 0                               IM NAYEON               NaN        Dance
# 1  Dream Your Life Away (Special Edition)               NaN  Alternative
# 2                  Memories...Do Not Open  The Chainsmokers        Dance
#
#   rating  track_price  collection_price          release_date  \
# 0  Clean         1.29              6.99  2022-06-24T12:00:00Z
# 1  Clean         1.29              9.99  2013-03-22T07:00:00Z
# 2  Clean         1.29              9.99  2017-02-22T08:00:00Z
#
#    track_time_millis country currency  \
# 0             168107     USA      USD
# 1             202019     USA      USD
# ...

# %%
# Display the data types of each column

print("Data Types: \n", df.dtypes)

# Describe the DataFrame
print("Statistical Summary: \n", df.describe())
# Out:
# Data Types:
#  track_id               int64
# track_name               str
# artist_name              str
# collection_name          str
# album_artist             str
# genre                    str
# rating                   str
# track_price          float64
# collection_price     float64
# release_date             str
# track_time_millis      int64
# country                  str
# currency                 str
# preview_url              str
# artwork_url              str
# Artist_age             int64
# dtype: object
# Statistical Summary:
#             track_id  track_price  collection_price  track_time_millis  \
# count  3.000000e+00         3.00          3.000000           3.000000
# mean   1.284739e+09         1.29          8.990000      205763.666667
# std    3.087895e+08         0.00          1.732051       39661.804514
# min    1.022164e+09         1.29          6.990000      168107.000000
# 25%    1.114642e+09         1.29          8.490000      185063.000000
# ...

# %%
df.describe()
# Out:
#            track_id  track_price  collection_price  track_time_millis  \
# count  3.000000e+00         3.00          3.000000           3.000000
# mean   1.284739e+09         1.29          8.990000      205763.666667
# std    3.087895e+08         0.00          1.732051       39661.804514
# min    1.022164e+09         1.29          6.990000      168107.000000
# 25%    1.114642e+09         1.29          8.490000      185063.000000
# 50%    1.207120e+09         1.29          9.990000      202019.000000
# 75%    1.416027e+09         1.29          9.990000      224592.000000
# max    1.624933e+09         1.29          9.990000      247165.000000
#
#        Artist_age
# count    3.000000
# mean    47.666667
# std     19.857828
# min     25.000000
# 25%     40.500000
# 50%     56.000000
# 75%     59.000000
# max     62.000000
