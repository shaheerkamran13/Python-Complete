# %% [markdown]
# # Working with File Paths

# %%
# create a new directory
import os
new_directory = 'package'

os.mkdir(new_directory)
print(f"Directory {new_directory} create")
# Out:
# Directory package create

# %%
# Listing files and directories

items = os.listdir('.')
print(items)
# Out:
# ['filePathsWorking.ipynb', 'package']

# %%
# Joining Paths --- Important

dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join( os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# d:\Udemy_Langgraph_Langchain\1_Python_preReq\FilePaths\folder\file.txt

# %%
path = 'example.csv'

if os.path.exists(path):
    print(f"The path {path} exists")

else:
    print(f'The path {path} does not exists')
# Out:
# The path example.csv exists

# %%
# check if the path is a file or directory

import os 
path = 'package'
if os.path.isfile(path):
    print(f"The path {path} is a file")
elif os.path.isdir(path):
    print(f"The path {path} is a directory")

else:
    print("The path {path} is neither a file nor a directory")
# Out:
# The path package is a directory

# %%
# Getting the absolute path
# Absolute path is the complete path


relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\Udemy_Langgraph_Langchain\1_Python_preReq\FilePaths\example.txt
