# %%
## File and Directory Access

import os
os.getcwd()
# Out:
# 'd:\\Udemy_Langgraph_Langchain\\1_Python_preReq'

# %%
# High level operations on files and collections of files

import shutil
shutil.copyfile('my_file.txt',"shaheer.txt")
# Out:
# 'shaheer.txt'

# %%
# Data Serialization

import json
data = {'name':'shaheer', 'age':23}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "shaheer", "age": 23}
# <class 'str'>
# {'name': 'shaheer', 'age': 23}
# <class 'dict'>

# %%
# csv

import csv
with open('example.csv', mode = 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Shaheer',23])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Shaheer', '23']

# %%
# datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)


yesterday = now - timedelta(days=6)

print(yesterday)
# Out:
# 2026-02-20 01:47:49.799891
# 2026-02-14 01:47:49.799891

# %%
# time

import time
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1771534116.6354702
# 1771534118.636277

# %%
# Regular Expressions

import re
pattern = r'\d+'

text = "There are 123 apples 456"
match = re.search(pattern,text)

print(match.group())
# Out:
# 123
