# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths

maths.addition(2,6)
# Out:
# 8

# %%
from package.maths import substraction

substraction(10,7)
# Out:
# 3
